# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
n=1000
ranmat = np.asmatrix(np.random.randn(n,n))
ranmat = ranmat/(n**0.5)

# %%
eigen = np.linalg.eig(ranmat)
xx = np.real(eigen[0])
yy = np.imag(eigen[0])
plt.axis('equal')
plt.scatter(xx , yy, s=5)
